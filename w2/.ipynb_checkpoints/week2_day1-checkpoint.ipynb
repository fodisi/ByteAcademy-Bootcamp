# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#let's create a series
s = pd.Series([1,3,5,np.nan,6,8])

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range('20180101', periods=7)

# %%
dates
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                '2018-01-05', '2018-01-06', '2018-01-07'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(7,4), index=dates, columns=list('ABCD'))

# %%
df
# Out:
#                    A         B         C         D
# 2018-01-01  0.399245  3.225371 -0.469659  0.803117
# 2018-01-02 -0.443734  0.495738  1.640580  0.206601
# 2018-01-03 -1.370823 -0.524576 -0.212160 -1.315658
# 2018-01-04  0.271307 -0.898377  1.138198 -0.185253
# 2018-01-05 -1.157956  0.029416 -0.057367 -1.897794
# 2018-01-06 -0.338417 -0.276740 -0.047706  0.909270
# 2018-01-07  0.574461  1.867244 -0.519084 -0.391244

# %%
df2 = pd.DataFrame({'A':1.,
                   'B':pd.Timestamp('20180602'),
                   'C':pd.Series(1,index=list(range(4)), dtype='float32'),
                   'D':np.array([3]*4,dtype='int32'),
                   'E':pd.Categorical(['test', 'train', 'test', 'train']),
                   'F':'foo'})

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df.head(2)
# Out:
#                    A         B         C         D
# 2018-01-01  0.399245  3.225371 -0.469659  0.803117
# 2018-01-02 -0.443734  0.495738  1.640580  0.206601

# %%
df.tail(4)
# Out:
#                    A         B         C         D
# 2018-01-04  0.271307 -0.898377  1.138198 -0.185253
# 2018-01-05 -1.157956  0.029416 -0.057367 -1.897794
# 2018-01-06 -0.338417 -0.276740 -0.047706  0.909270
# 2018-01-07  0.574461  1.867244 -0.519084 -0.391244

# %%
df.index
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                '2018-01-05', '2018-01-06', '2018-01-07'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.values
# Out:
# array([[ 0.3992446 ,  3.22537125, -0.46965925,  0.80311698],
#        [-0.44373392,  0.49573751,  1.64057995,  0.20660087],
#        [-1.37082319, -0.52457584, -0.21215971, -1.31565805],
#        [ 0.27130719, -0.89837671,  1.1381981 , -0.18525321],
#        [-1.15795616,  0.02941624, -0.05736747, -1.89779378],
#        [-0.33841682, -0.27673991, -0.04770649,  0.90927028],
#        [ 0.57446141,  1.86724398, -0.51908419, -0.39124417]])

# %%
df.describe()
# Out:
#               A         B         C         D
# count  7.000000  7.000000  7.000000  7.000000
# mean  -0.295131  0.559725  0.210400 -0.267280
# std    0.762096  1.477726  0.838424  1.043580
# min   -1.370823 -0.898377 -0.519084 -1.897794
# 25%   -0.800845 -0.400658 -0.340909 -0.853451
# 50%   -0.338417  0.029416 -0.057367 -0.185253
# 75%    0.335276  1.181491  0.545246  0.504859
# max    0.574461  3.225371  1.640580  0.909270

# %%
df.T
# Out:
#    2018-01-01  2018-01-02  2018-01-03  2018-01-04  2018-01-05  2018-01-06  \
# A    0.399245   -0.443734   -1.370823    0.271307   -1.157956   -0.338417
# B    3.225371    0.495738   -0.524576   -0.898377    0.029416   -0.276740
# C   -0.469659    1.640580   -0.212160    1.138198   -0.057367   -0.047706
# D    0.803117    0.206601   -1.315658   -0.185253   -1.897794    0.909270
#
#    2018-01-07
# A    0.574461
# B    1.867244
# C   -0.519084
# D   -0.391244

# %%
df
# Out:
#                    A         B         C         D
# 2018-01-01  0.399245  3.225371 -0.469659  0.803117
# 2018-01-02 -0.443734  0.495738  1.640580  0.206601
# 2018-01-03 -1.370823 -0.524576 -0.212160 -1.315658
# 2018-01-04  0.271307 -0.898377  1.138198 -0.185253
# 2018-01-05 -1.157956  0.029416 -0.057367 -1.897794
# 2018-01-06 -0.338417 -0.276740 -0.047706  0.909270
# 2018-01-07  0.574461  1.867244 -0.519084 -0.391244

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2018-01-01  0.803117 -0.469659  3.225371  0.399245
# 2018-01-02  0.206601  1.640580  0.495738 -0.443734
# 2018-01-03 -1.315658 -0.212160 -0.524576 -1.370823
# 2018-01-04 -0.185253  1.138198 -0.898377  0.271307
# 2018-01-05 -1.897794 -0.057367  0.029416 -1.157956
# 2018-01-06  0.909270 -0.047706 -0.276740 -0.338417
# 2018-01-07 -0.391244 -0.519084  1.867244  0.574461

# %%
df.sort_values(by='B')
# Out:
#                    A         B         C         D
# 2018-01-04  0.271307 -0.898377  1.138198 -0.185253
# 2018-01-03 -1.370823 -0.524576 -0.212160 -1.315658
# 2018-01-06 -0.338417 -0.276740 -0.047706  0.909270
# 2018-01-05 -1.157956  0.029416 -0.057367 -1.897794
# 2018-01-02 -0.443734  0.495738  1.640580  0.206601
# 2018-01-07  0.574461  1.867244 -0.519084 -0.391244
# 2018-01-01  0.399245  3.225371 -0.469659  0.803117

# %%
df.sort_values(by='D')
# Out:
#                    A         B         C         D
# 2018-01-05 -1.157956  0.029416 -0.057367 -1.897794
# 2018-01-03 -1.370823 -0.524576 -0.212160 -1.315658
# 2018-01-07  0.574461  1.867244 -0.519084 -0.391244
# 2018-01-04  0.271307 -0.898377  1.138198 -0.185253
# 2018-01-02 -0.443734  0.495738  1.640580  0.206601
# 2018-01-01  0.399245  3.225371 -0.469659  0.803117
# 2018-01-06 -0.338417 -0.276740 -0.047706  0.909270

# %%
df['A']
# Out:
# 2018-01-01    0.399245
# 2018-01-02   -0.443734
# 2018-01-03   -1.370823
# 2018-01-04    0.271307
# 2018-01-05   -1.157956
# 2018-01-06   -0.338417
# 2018-01-07    0.574461
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2018-01-01  0.399245  3.225371 -0.469659  0.803117
# 2018-01-02 -0.443734  0.495738  1.640580  0.206601
# 2018-01-03 -1.370823 -0.524576 -0.212160 -1.315658

# %%
df[:1]
# Out:
#                    A         B         C         D
# 2018-01-01  0.399245  3.225371 -0.469659  0.803117

# %%
df[:-1]
# Out:
#                    A         B         C         D
# 2018-01-01  0.399245  3.225371 -0.469659  0.803117
# 2018-01-02 -0.443734  0.495738  1.640580  0.206601
# 2018-01-03 -1.370823 -0.524576 -0.212160 -1.315658
# 2018-01-04  0.271307 -0.898377  1.138198 -0.185253
# 2018-01-05 -1.157956  0.029416 -0.057367 -1.897794
# 2018-01-06 -0.338417 -0.276740 -0.047706  0.909270

# %%
df['20180103':'20180105']
# Out:
#                    A         B         C         D
# 2018-01-03 -1.370823 -0.524576 -0.212160 -1.315658
# 2018-01-04  0.271307 -0.898377  1.138198 -0.185253
# 2018-01-05 -1.157956  0.029416 -0.057367 -1.897794

# %%
df['20180103':'20180105']['A']
# Out:
# 2018-01-03   -1.370823
# 2018-01-04    0.271307
# 2018-01-05   -1.157956
# Freq: D, Name: A, dtype: float64

# %%
df.loc['20180103':'20180105',['B','C']]
# Out:
#                    B         C
# 2018-01-03 -0.524576 -0.212160
# 2018-01-04 -0.898377  1.138198
# 2018-01-05  0.029416 -0.057367

# %%
df.loc['20180103',['A','B','C']]
# Out:
# A   -1.370823
# B   -0.524576
# C   -0.212160
# Name: 2018-01-03 00:00:00, dtype: float64

# %%
df.loc[dates[0], 'A']
# Out:
# 0.3992445958057284

# %%
df
# Out:
#                    A         B         C         D
# 2018-01-01  0.399245  3.225371 -0.469659  0.803117
# 2018-01-02 -0.443734  0.495738  1.640580  0.206601
# 2018-01-03 -1.370823 -0.524576 -0.212160 -1.315658
# 2018-01-04  0.271307 -0.898377  1.138198 -0.185253
# 2018-01-05 -1.157956  0.029416 -0.057367 -1.897794
# 2018-01-06 -0.338417 -0.276740 -0.047706  0.909270
# 2018-01-07  0.574461  1.867244 -0.519084 -0.391244

# %%
df.at[dates[0], 'A']
# Out:
# 0.3992445958057284

# %%
df.iloc[3] #integer locate
# Out:
# A    0.271307
# B   -0.898377
# C    1.138198
# D   -0.185253
# Name: 2018-01-04 00:00:00, dtype: float64

# %%
df.iloc[[1,2,4],[0,2]]  #integer locate
# Out:
#                    A         C
# 2018-01-02 -0.443734  1.640580
# 2018-01-03 -1.370823 -0.212160
# 2018-01-05 -1.157956 -0.057367

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns)+['E'])

# %%
df1.loc[dates[0]:dates[1], 'E']=1

# %%
df1
# Out:
#                    A         B         C         D    E
# 2018-01-01  0.399245  3.225371 -0.469659  0.803117  1.0
# 2018-01-02 -0.443734  0.495738  1.640580  0.206601  1.0
# 2018-01-03 -1.370823 -0.524576 -0.212160 -1.315658  NaN
# 2018-01-04  0.271307 -0.898377  1.138198 -0.185253  NaN

# %%
df
# Out:
#                    A         B         C         D    E
# 2018-01-01  0.399245  3.225371 -0.469659  0.803117  1.0
# 2018-01-02 -0.443734  0.495738  1.640580  0.206601  1.0
# 2018-01-03 -1.370823 -0.524576 -0.212160 -1.315658  NaN
# 2018-01-04  0.271307 -0.898377  1.138198 -0.185253  NaN
# 2018-01-05 -1.157956  0.029416 -0.057367 -1.897794  NaN
# 2018-01-06 -0.338417 -0.276740 -0.047706  0.909270  NaN
# 2018-01-07  0.574461  1.867244 -0.519084 -0.391244  NaN

# %%
df1.dropna(how='any')
# Out:
#                    A         B         C         D    E
# 2018-01-01  0.399245  3.225371 -0.469659  0.803117  1.0
# 2018-01-02 -0.443734  0.495738  1.640580  0.206601  1.0

# %%
df1
# Out:
#                    A         B         C         D    E
# 2018-01-01  0.399245  3.225371 -0.469659  0.803117  1.0
# 2018-01-02 -0.443734  0.495738  1.640580  0.206601  1.0
# 2018-01-03 -1.370823 -0.524576 -0.212160 -1.315658  NaN
# 2018-01-04  0.271307 -0.898377  1.138198 -0.185253  NaN

# %%
df.fillna(value=4)
# Out:
#                    A         B         C         D    E
# 2018-01-01  0.399245  3.225371 -0.469659  0.803117  1.0
# 2018-01-02 -0.443734  0.495738  1.640580  0.206601  1.0
# 2018-01-03 -1.370823 -0.524576 -0.212160 -1.315658  4.0
# 2018-01-04  0.271307 -0.898377  1.138198 -0.185253  4.0
# 2018-01-05 -1.157956  0.029416 -0.057367 -1.897794  4.0
# 2018-01-06 -0.338417 -0.276740 -0.047706  0.909270  4.0
# 2018-01-07  0.574461  1.867244 -0.519084 -0.391244  4.0

# %%
df1.fillna(value=4)
# Out:
#                    A         B         C         D    E
# 2018-01-01  0.399245  3.225371 -0.469659  0.803117  1.0
# 2018-01-02 -0.443734  0.495738  1.640580  0.206601  1.0
# 2018-01-03 -1.370823 -0.524576 -0.212160 -1.315658  4.0
# 2018-01-04  0.271307 -0.898377  1.138198 -0.185253  4.0

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      E
# 2018-01-01  False  False  False  False  False
# 2018-01-02  False  False  False  False  False
# 2018-01-03  False  False  False  False   True
# 2018-01-04  False  False  False  False   True

# %%
df.mean()
# Out:
# A   -0.295131
# B    0.559725
# C    0.210400
# D   -0.267280
# E    1.000000
# dtype: float64

# %%
df.mean(1)
# Out:
# 2018-01-01    0.991615
# 2018-01-02    0.579837
# 2018-01-03   -0.855804
# 2018-01-04    0.081469
# 2018-01-05   -0.770925
# 2018-01-06    0.061602
# 2018-01-07    0.382844
# Freq: D, dtype: float64
